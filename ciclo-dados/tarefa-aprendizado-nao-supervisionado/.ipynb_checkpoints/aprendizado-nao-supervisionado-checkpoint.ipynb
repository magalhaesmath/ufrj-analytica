# %% [markdown]
# # Autor: Matheus Magalhães
# ### Tarefa Aprendizado Não Supervisionado

# %%
# Importando as bibliotecas necessárias:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ### Tratamento e Limpeza dos Dados
# Começarei fazendo a limpeza e o tratamento dos dados do **.csv**.

# %%
# Importando o .csv:
df = pd.read_csv("credit_card_customer_data.csv")

# %%
# Vendo a estrutura do df:
df.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made
# 0                  1                    1                 0
# 1                  0                   10                 9
# 2                  1                    3                 4
# 3                  1                    1                 4
# 4                  0                   12                 3

# %%
# Verificando formato do df:
print(f"Dimensões da matriz: {df.shape} \n")

# Verificando dados nulos:
print(f"Números de nulos por atributo:\n{df.isna().sum()}\n")

# Verificando dados duplicados:
print(f"Dados duplicados por atributo:\n{df.nunique()}\n")

# Verificando os tipos de dados:
print(f"Tipos de dados por atributo:\n{df.dtypes}\n")
# Out:
# Dimensões da matriz: (660, 7)
#
# Números de nulos por atributo:
# Sl_No                  0
# Customer Key           0
# Avg_Credit_Limit       0
# Total_Credit_Cards     0
# Total_visits_bank      0
# Total_visits_online    0
# Total_calls_made       0
# dtype: int64
#
# Dados duplicados por atributo:
# Sl_No                  660
# Customer Key           655
# Avg_Credit_Limit       110
# Total_Credit_Cards      10
# Total_visits_bank        6
# Total_visits_online     16
# Total_calls_made        11
# dtype: int64
#
# Tipos de dados por atributo:
# Sl_No                  int64
# Customer Key           int64
# Avg_Credit_Limit       int64
# Total_Credit_Cards     int64
# Total_visits_bank      int64
# Total_visits_online    int64
# Total_calls_made       int64
# dtype: object

# %% [markdown]
# ### Conclusões iniciais
# O DataFrame não possi valores nulos ou inválidos. No entanto, possui 5 "Customer Key" repetidas, portanto, vou verificar quais são e perceber se elas são linhas idênticas ou não.

# %%
# Printando as 'customer_key' duplicadas:
duplicadas = df[df['Customer Key'].duplicated(keep=False)]
duplicadas.sort_values('Customer Key')
# Out:
#      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 48      49         37252              6000                   4
# 432    433         37252             59000                   6
# 4        5         47437            100000                   6
# 332    333         47437             17000                   7
# 411    412         50706             44000                   4
# 541    542         50706             60000                   7
# 391    392         96929             13000                   4
# 398    399         96929             67000                   6
# 104    105         97935             17000                   2
# 632    633         97935            187000                   7
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 48                   0                    2                 8
# 432                  2                    1                 2
# 4                    0                   12                 3
# ...

# %% [markdown]
# Estou supondo que essas duplicatas são dados extraídos, do mesmo cliente, em épocas distintas. Por isso, vou agregar estes dados pelo .max(), pois, a tendência é que, com o passar dos anos, seu limite, total de cartões, visitas ao banco, etc., aumentem.

# %%
# Agregando pela 'Customer Key':
df = df.groupby('Customer Key').agg({
    'Avg_Credit_Limit': 'max',
    'Total_Credit_Cards': 'max',
    'Total_visits_bank': 'max',
    'Total_visits_online': 'max',
    'Total_calls_made': 'max'
}).reset_index()

# %% [markdown]
# Repare que, como agreguei pela **'Customer Key'**, o atributo **'Sl_No'** (*Serial Number*) será descartado, e os clientes serão identificados somente pela **'Customer Key'**.

# %%
# Verificando se, de fato, não existem repetições em 'Customer Key':
print(f"Valores únicos em 'Customer Key': {df['Customer Key'].nunique()}")
print(f"Total de linhas no DF: {df.shape[0]}")
# Out:
# Valores únicos em 'Customer Key': 655
# Total de linhas no DF: 655

# %% [markdown]
# Como podemos ver pela célula acima, não existem valores repetidos em **'Customer Key'**. Sendo assim, **'Customer Key'** é uma **chave identificadora** válida.

# %%
# Métricas úteis sobre o df:
df.describe()
# Out:
#        Customer Key  Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# count    655.000000        655.000000           655.00000         655.000000
# mean   55058.158779      34690.076336             4.71145           2.409160
# std    25606.965469      37728.591465             2.17241           1.628467
# min    11265.000000       3000.000000             1.00000           0.000000
# 25%    33623.500000      10000.000000             3.00000           1.000000
# 50%    53898.000000      18000.000000             5.00000           2.000000
# 75%    77084.500000      48500.000000             6.00000           4.000000
# max    99843.000000     200000.000000            10.00000           5.000000
#
#        Total_visits_online  Total_calls_made
# count           655.000000        655.000000
# mean              2.619847          3.604580
# std               2.941931          2.864575
# min               0.000000          0.000000
# 25%               1.000000          1.000000
# ...

# %% [markdown]
# ### Gráficos

# %%
sns.set(style="whitegrid")

# %%
# Matriz de correlação das variáveis:
plt.figure(figsize=(6, 4))
corr = df[['Avg_Credit_Limit', 'Total_Credit_Cards', 'Total_visits_bank', 'Total_visits_online', 'Total_calls_made']].corr()
sns.heatmap(corr, annot=True, cmap='crest')
plt.title('Mapa de Correlação')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise de Correlação entre Variáveis
#
# A matriz de correlação revelou algumas relações significativas entre os atributos do conjunto de dados:
#
# 1. **Avg_Credit_Limit** possui uma correlação positiva forte com **Total_Credit_Cards** (0.61), sugerindo que clientes com mais cartões de crédito tendem a ter um limite médio maior.
#
# 2. **Avg_Credit_Limit** também apresenta uma correlação positiva moderada com **Total_visits_online** (0.55), o que pode indicar que clientes com maior limite utilizam mais o ambiente digital.
#
# 3. **Avg_Credit_Limit** possui ainda uma correlação negativa moderada com **Total_calls_made** (-0.39), indicando que clientes com maior limite médio fazem menos chamadas para o banco.
#
# 4. **Total_Credit_Cards** e **Total_visits_bank** apresentam uma correlação positiva moderada (0.32), sugerindo que clientes com mais cartões tendem a visitar mais o banco fisicamente.
#
# 5. **Total_Credit_Cards** e **Total_calls_made** apresentam uma correlação negativa forte (-0.64), sugerindo que clientes com mais cartões tendem a realizar menos chamadas.
#
# 6. **Total_visits_bank** e **Total_visits_online** têm uma correlação negativa significativa (-0.54), indicando uma substituição entre os canais de atendimento: clientes que visitam mais o banco fisicamente tendem a acessar menos os canais digitais, e vice-versa.
#
# 7. **Total_calls_made** também apresenta correlação negativa com **Total_visits_bank** (-0.51), sugerindo que mais chamadas podem estar associadas a um menor envolvimento presencial com a agência bancária.

# %%
# Histograma dos limites de crédito:
plt.figure(figsize=(8, 4))
sns.histplot(df['Avg_Credit_Limit'], bins=40, kde=True)
plt.title('Distribuição dos Limites de Crédito')
plt.xlabel('Limite (R$)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %%
# Histograma do número de cartões:
plt.figure(figsize=(8, 4))
sns.histplot(df['Total_Credit_Cards'], bins=40, kde=True)
plt.title('Distribuição do Número de Cartões de Crédito')
plt.xlabel('Número de Cartões')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %%
# Boxplot dos limites por número de cartões:
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Total_Credit_Cards', y='Avg_Credit_Limit')
plt.xticks(rotation=45)
plt.title('Limite de Crédito por Número de Cartões')
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Avg_Credit_Limit' e 'Total_Credit_Cards':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_Credit_Cards", y="Avg_Credit_Limit", color="blue", alpha=0.7)

plt.title("Relação entre Total de Cartões e Limite Médio de Crédito")
plt.xlabel("Total de Cartões de Crédito")
plt.ylabel("Limite Médio de Crédito")
plt.tight_layout()
plt.show()

# %%
# Histograma do número de visitas online:
plt.figure(figsize=(8, 4))
sns.histplot(df['Total_visits_online'], bins=40, kde=True)
plt.title('Distribuição do Número de Visitas Online')
plt.xlabel('Número de Visitas Online')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %%
# Boxplot dos limites por número de visitas online:
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Total_visits_online', y='Avg_Credit_Limit')
plt.xticks(rotation=45)
plt.title('Limite de Crédito por Número de Visitas Online')
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Avg_Credit_Limit' e 'Total_visits_online':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_visits_online", y="Avg_Credit_Limit", color="blue", alpha=0.7)

plt.title("Relação entre Total de Visitas Online e Limite Médio de Crédito")
plt.xlabel("Total de Visitas Online")
plt.ylabel("Limite Médio de Crédito")
plt.tight_layout()
plt.show()

# %%
# Boxplot dos limites por número de chamadas:
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Total_calls_made', y='Avg_Credit_Limit')
plt.xticks(rotation=45)
plt.title('Limite de Crédito por Número de Chamadas Feitas')
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Avg_Credit_Limit' e 'Total_calls_made':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_calls_made", y="Avg_Credit_Limit", color="blue", alpha=0.7)

plt.title("Relação entre Total de Chamadas Feitas e Limite Médio de Crédito")
plt.xlabel("Total de Chamdas Feitas")
plt.ylabel("Limite Médio de Crédito")
plt.tight_layout()
plt.show()

# %%
# Boxplot do número de cartões por número de visitas ao banco:
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Total_visits_bank', y='Total_Credit_Cards')
plt.xticks(rotation=45)
plt.title('Número de Cartões por Número de Visitas ao Banco')
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Total_Credit_Cards' e 'Total_visits_bank':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_visits_bank", y="Total_Credit_Cards", color="blue", alpha=0.7)

plt.title("Relação entre Total de Visitas ao Banco e Número de Cartões")
plt.xlabel("Total de Visitas ao Banco")
plt.ylabel("Total de Cartões")
plt.tight_layout()
plt.show()

# %%
# Boxplot do número de cartões por número de chamadas ao banco:
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Total_calls_made', y='Total_Credit_Cards')
plt.xticks(rotation=45)
plt.title('Número de Cartões por Número de Chamadas ao Banco')
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Total_Credit_Cards' e 'Total_calls_made':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_calls_made", y="Total_Credit_Cards", color="blue", alpha=0.7)

plt.title("Relação entre Total de Chamadas Feitas e Número de Cartões")
plt.xlabel("Total de Chamadas Feitas")
plt.ylabel("Total de Cartões")
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Total_visits_bank' e 'Total_visits_online':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_visits_bank", y="Total_visits_online", color="blue", alpha=0.7)

plt.title("Relação entre Total de Visitas Presenciais e Total de Visitas Online")
plt.xlabel("Total de Visitas Presenciais")
plt.ylabel("Total de Visitas Online")
plt.tight_layout()
plt.show()

# %%
# Scatter plot entre 'Total_visits_bank' e 'Total_calls_made':
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="Total_visits_bank", y="Total_calls_made", color="blue", alpha=0.7)

plt.title("Relação entre Total de Visitas Presenciais e Total de Chamadas")
plt.xlabel("Total de Visitas Presenciais")
plt.ylabel("Total de Chamadas")
plt.tight_layout()
plt.show()

# %% [markdown]
# Percebemos, pelos gráficos acima, que possuímos alguns dados distribuídos de maneira heterogênea, não temos muitos *outliers* e as correlações lineares se mostraram verdadeiras. Portanto, percebi que posso aplicar o PCA para reduzir a dimensionalidade destes dados e, em seguida, clusterizá-los, assim percebendo padrões de clientes.
#
# **Observação**: a constatação da linearidade nas correlações é de suma importância, pois o PCA é uma técnica essencialmente linear, ou seja, o PCA não lida bem com relacões não lineares e, para estas, possuímos outros algoritmos e técnicas.

# %% [markdown]
# ## Principal Component Analysis (PCA)
# Antes de aplicar o PCA, vou fazer Feature Scalling nos dados, para que escalas diferentes não atrapalhem a redução de dimensionalidade. Para isso, vou desprezar a coluna 'Customer Key', pois só serve de identificador, e normalizar as demais usando Standard Scaler.

# %%
# Selecionando as colunas que vou normalizar:
colunas = ['Avg_Credit_Limit', 'Total_Credit_Cards', 'Total_visits_bank', 'Total_visits_online', 'Total_calls_made']

scaler = StandardScaler()

df_normalizado = scaler.fit_transform(df[colunas])

df_normalizado = pd.DataFrame(df_normalizado, columns=colunas, index=df.index)

pca = PCA()
pca.fit(df_normalizado) 

# Variância explicada por cada componente
variancia = pca.explained_variance_ratio_

# %% [markdown]
# ### Como decidir o número de dimensões?
#
# Para determinar quantas componentes principais manter após o PCA, utiliza-se o **Método do Cotovelo**:
#
# 1. **Cálculo da Variância Explicada**
#    Para cada componente \(i\), calcula-se a variância explicada como:
#
#    $$
#    \mathrm{Variância}_i \;=\; \frac{\lambda_i}{\displaystyle\sum_{j=1}^{n} \lambda_j}
#    $$
#
#    em que $(\lambda_i)$ é o autovalor da $i$-ésima componente.
#
# 2. **Gráfico de Variância vs. Número de Componentes**
#    Plota-se a variância explicada (ou cumulativa) em função do número de componentes. A curva normalmente decresce rapidamente no início e depois se estabiliza.
#
# 3. **Identificação do Cotovelo**
#    O “cotovelo” é o ponto em que a curva começa a se achatar, indicando que componentes adicionais geram ganhos marginais de variância. Esse é o número ideal de dimensões a manter.
#
# > **Vantagem:** aplica um critério visual e objetivo para balancear simplificação do modelo e retenção de informação relevante.

# %%
# Gráfico do cotovelo:
plt.figure(figsize=(8, 5))
sns.lineplot(x=range(1, len(variancia) + 1), y=variancia, marker='o')

plt.xlabel('Número de Componentes Principais')
plt.ylabel('Variância Explicada (%)')
plt.title('Gráfico de Cotovelo - PCA')
plt.xticks(range(1, len(variancia) + 1))
plt.show()

# %% [markdown]
# Como podemos notar acima, apesar da curva se estabilizar a partir da 3ª componente principal, as duas componentes principais já representam aproximadamente 82% da variância. Sendo assim, irei reduzir os dados com o PCA para o espaço $ \mathbb{R}^2 $.

# %%
# Reduzindo dimensão:

# Inicializando o PCA para 2 dimensões:
pca = PCA(n_components=2)

# Aplicando o PCA:
dados_R2 = pca.fit_transform(df_normalizado)

# Transformando os dados reduzidos em df:
dados_R2 = pd.DataFrame(dados_R2, columns=['PCA1', 'PCA2'], index=df.index)

# %%
dados_R2.head()
# Out:
#        PCA1      PCA2
# 0  1.624790 -0.418682
# 1  1.009123 -1.493896
# 2 -1.087188  0.044760
# 3  1.367327 -2.040991
# 4  0.628004 -0.612780

# %%
# Plotando os dados reduzidos:
sns.scatterplot(data=dados_R2, x="PCA1", y="PCA2", color="green", alpha=0.7)

plt.title("Dados reduzidos para R2")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.tight_layout()
plt.show()

# %% [markdown]
# Perceba como, só ao olhar, podemos perceber clusters se formando. Podemos dizer que, "pelo olho", o número ideal de clusters seria 3. Porém, quando não podemos visualizar os dados para isso, podemos fazer uma espécie de cotovelo de clusters.<br>
# Como temos dados que, visualmente, já se destacam, usarei o algoritmo de K-Means para clusterizar estes dados.

# %% [markdown]
# ### Método do Cotovelo para Clustering
#
# O **método do cotovelo** é uma técnica utilizada para determinar o número ideal de clusters em uma análise de clustering, como o **KMeans**. A ideia principal é calcular a **inércia** (soma das distâncias quadradas dentro de cada cluster) para diferentes valores de **K** (número de clusters) e identificar onde a curva “faz um cotovelo”.
#
# 1. **Cálculo da Inércia**
#    Para cada K, ajusta-se o KMeans e obtém-se a inércia, que mede o quão próximos os pontos estão do centro de seus clusters.
#
# 2. **Plotagem do Gráfico**
#    Plotamos a inércia em função de K. Geralmente, a inércia diminui conforme aumentamos K, mas chega um ponto em que o ganho de redução é marginal.
#
# 3. **Identificação do Cotovelo**
#    O “cotovelo” é o ponto em que a curva começa a se estabilizar — ou seja, onde o benefício de adicionar mais clusters se torna pequeno. Esse K corresponde ao número ideal de clusters.
#
# > **Vantagem:** fornece um critério formal para escolher K, evitando decisões arbitrárias.

# %%
# Definindo o intervalo de valores de K (número de clusters):
K_range = range(1, 11)  # de 1 a 10 clusters

# Lista para armazenar as inércias:
inercia = []

# Calculando a inércia para cada K:
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(dados_R2)
    inercia.append(kmeans.inertia_)

# Plotando o gráfico do método do cotovelo:
plt.figure(figsize=(8, 5))
plt.plot(K_range, inercia, marker='o', linestyle='-', color='b')
plt.xlabel('Número de Clusters (K)')
plt.ylabel('Inércia')
plt.title('Método do Cotovelo para Determinação de K')
plt.grid(True)
plt.show()
# Out:
# C:\Users\emine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\emine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\emine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %% [markdown]
# Perceba que o cotovelo do gráfico confirma nossa hipótese visual: a estabilização ocorre com 3 clusters, ou seja, este é o número ideal de clusters para os dados que temos.

# %%
# Clusterizando em 3 clusters:
kmeans = KMeans(n_clusters=3, random_state=42)
dados_R2['Cluster'] = kmeans.fit_predict(dados_R2)  # Adicionando a coluna 'Cluster' ao DataFrame

# Visualizando os clusters:
sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', data=dados_R2, palette='viridis', s=100)
plt.title('Clusters gerados pelo K-Means')
plt.show()
# Out:
# C:\Users\emine\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %% [markdown]
# Perceba como os 3 clusters formados após o K-Means estão bem definidos no gráfico. Isso significa que existem 3 grupos, bem definidos, de clientes. Agora, vou adicionar a coluna 'Cluster' ao df original e, após isso, tentar ver algum sentido ou padrão nos grupos.

# %%
# Agora, vou adicionar a coluna de cluster ao df original:
df['Cluster'] = dados_R2['Cluster'].values

# %%
df.head()
# Out:
#    Customer Key  Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 0         11265             51000                   7                  3
# 1         11398             12000                   6                  5
# 2         11412             19000                   2                  2
# 3         11466              9000                   7                  5
# 4         11562             38000                   4                  3
#
#    Total_visits_online  Total_calls_made  Cluster
# 0                    2                 0        0
# 1                    2                 1        0
# 2                    3                 4        1
# 3                    0                 0        0
# 4                    2                 0        0

# %%
df_medias = df.groupby('Cluster')[['Avg_Credit_Limit', 'Total_Credit_Cards', 'Total_visits_bank', 'Total_visits_online', 'Total_calls_made']].mean().reset_index()
df_medias.sort_values(by='Avg_Credit_Limit')
# Out:
#    Cluster  Avg_Credit_Limit  Total_Credit_Cards  Total_visits_bank  \
# 1        1      12390.134529            2.421525           0.941704
# 0        0      33787.958115            5.518325           3.494764
# 2        2     141040.000000            8.760000           0.660000
#
#    Total_visits_online  Total_calls_made
# 1             3.560538          6.856502
# 0             0.986911          2.010471
# 2            10.900000          1.280000

# %% [markdown]
# ### 🎯 Análise dos Grupos de Clientes por Cluster
#
# A análise dos dados agrupados por **cluster** revela que os grupos foram segmentados, principalmente, com base na **média do limite de crédito**.
#
# Temos, portanto, três grupos distintos:
# - 💳 **Baixo limite de crédito**
# - 💳 **Limite intermediário**
# - 💳 **Alto limite de crédito**
#
# Essa classificação está **diretamente relacionada ao número médio de cartões de crédito**: quanto maior o limite, maior a quantidade de cartões, como já foi observado na Análise Exploratória.
#
# ---
#
# ### 🔍 Comportamento por Canal de Atendimento
#
# 1. **Grupo com menor limite de crédito**:
#    - Usa **pouco** o canal **presencial**;
#    - Usa **moderadamente** o canal **online**;
#    - Utiliza **principalmente** o canal **telefônico**.
#
# 2. **Grupo com limite intermediário**:
#    - Usa **moderadamente** os canais **presencial** e **telefônico**;
#    - Quase **não utiliza** o canal **online**.
#
# 3. **Grupo com maior limite de crédito**:
#    - Usa **intensamente** o canal **online**;
#    - Utiliza **pouco** o canal **telefônico**;
#    - Quase **não usa** o canal **presencial**.
#
# ---
#
# ### 💡 Aplicações Estratégicas
#
# Essa segmentação pode ser extremamente útil para diversas ações estratégicas do banco:
#
# 1. **Planejamento de investimentos**: determinar quais canais devem receber mais atenção e recursos, com foco no tipo de clientes que o banco deseja captar ou fidelizar;
# 2. **Campanhas de marketing personalizadas**: alinhar a abordagem com os canais preferenciais de cada grupo, focando em melhorias que realmente importem para aquele setor de clientes;
# 3. **Melhoria da experiência do cliente**: adaptar os canais de atendimento às expectativas e comportamentos dos principais grupos de clientes.
